# %% [markdown]
# <a href="https://colab.research.google.com/github/mill-5/2025-1-myclass-BDA/blob/main/inclass/10w_B_wed_0507_easy_ch08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##단원 08 그래프 만들기

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install koreanize_matplotlib

# %%
# %config inlineBackend.figure_format = 'retina'

# %%
pd.set_option('display.precision', 2)

# %%
# !git clone https://github.com/ai7dnn/data
# Out:
# fatal: destination path 'data' already exists and is not an empty directory.

# %%
mpg = pd.read_csv('./data/mpg.csv')
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  category      234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 20.2+ KB

# %%
mpg.isna().sum()
# Out:
# manufacturer    0
# model           0
# displ           0
# year            0
# cyl             0
# trans           0
# drv             0
# cty             0
# hwy             0
# fl              0
# category        0
# dtype: int64

# %%
mpg.isna().sum().sum()
# Out:
# np.int64(0)

# %%
plt.rcParams.update({'figure.figsize':[4, 2.5]})

# %%
import koreanize_matplotlib

sns.scatterplot(data=mpg, x='displ', y='hwy');

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy',alpha=.3); #alpha 낮추면 중복 된거 쉽게 볼 수 있음

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy',alpha=.3).set(xlim=[3,6]);

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy',alpha=.3).set(xlim=[3,6], ylim=[15,30]);

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy',hue='drv', alpha=.3);

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy',hue='category');

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy',hue='category');
plt.legend(loc='upper right');

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy',hue='category');
plt.legend(loc=3);

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy',hue='category');
plt.legend(loc='lower left');

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy',hue='category');
plt.legend(loc='lower right');

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy',hue='category');
plt.legend(loc='upper right',bbox_to_anchor=(1,1));  #bbox_to_ancho가 있을때의 loc는 다름

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy',hue='category');
plt.legend(loc='upper right',bbox_to_anchor=(0,1));

# %%
sns.scatterplot(data=mpg, x='displ', y='hwy',hue='category');
plt.legend(loc='upper right',bbox_to_anchor=(1,0));

# %%
sns.scatterplot(data=mpg, x='trans', y='hwy',hue='hwy');
plt.legend(loc='upper right',bbox_to_anchor=(1,0));

# %%
myPlot = sns.scatterplot(data=mpg, x='trans', y='hwy',hue='hwy');
myPlot.tick_params(axis='x', labelrotation=45);
plt.legend(loc='lower left',bbox_to_anchor=(1,0));

# %%
df_mpg =mpg.groupby('drv').agg(mean_hwy=('hwy','mean'))
df_mpg
# Out:
#      mean_hwy
# drv
# 4       19.17
# f       28.16
# r       21.00

# %%
sns.barplot(data=df, x='drv', y='mean_hwy');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-d17fc0d3fa30> in <cell line: 0>()
# ----> 1 sns.barplot(data=df, x='drv', y='mean_hwy');
#
# NameError: name 'df' is not defined

# %%
sns.barplot(data=df, x='drv', y='mean_hwy', hue='drv');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-cd77a32871c9> in <cell line: 0>()
# ----> 1 sns.barplot(data=df, x='drv', y='mean_hwy', hue='drv');
#
# NameError: name 'df' is not defined

# %%
sns.barplot(data=mpg, x='drv', y='mean_hwy',hue='drv',order=['f','r','4']);
